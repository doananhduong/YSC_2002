# %%
import numpy as np
import pandas as pd
import xlwt
from scipy import stats
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_excel('./raw_data_90.xls')
data
# Out:
#       Unnamed: 0  Row ID        Order ID Order Date  Ship Date  \
# 0           2041    2042  CA-2016-122287 2016-06-18 2016-06-23
# 1           4336    4337  CA-2016-154795 2016-12-20 2016-12-24
# 2           1242    1243  US-2017-162859 2017-02-15 2017-02-22
# 3           2870    2871  CA-2015-148040 2015-03-22 2015-03-26
# 4           1519    1520  CA-2018-116204 2018-02-11 2018-02-14
# ...          ...     ...             ...        ...        ...
# 8989        9384    9385  CA-2018-100433 2018-08-11 2018-08-16
# 8990        2138    2139  US-2018-157896 2018-11-16 2018-11-16
# 8991        4508    4509  US-2015-138247 2015-12-24 2015-12-29
# 8992         365     366  CA-2015-123344 2015-09-24 2015-09-29
# 8993        1454    1455  CA-2017-133711 2017-11-26 2017-11-29
#
#            Ship Mode Customer ID     Customer Name      Segment  \
# 0     Standard Class    SN-20560      Skye Norling  Home Office
# 1     Standard Class    GZ-14470     Gary Zandusky     Consumer
# ...

# %%
data = data.assign(is_processed='False')
# Out:
#       Unnamed: 0  Row ID        Order ID Order Date  Ship Date  \
# 0           2041    2042  CA-2016-122287 2016-06-18 2016-06-23
# 1           4336    4337  CA-2016-154795 2016-12-20 2016-12-24
# 2           1242    1243  US-2017-162859 2017-02-15 2017-02-22
# 3           2870    2871  CA-2015-148040 2015-03-22 2015-03-26
# 4           1519    1520  CA-2018-116204 2018-02-11 2018-02-14
# ...          ...     ...             ...        ...        ...
# 8989        9384    9385  CA-2018-100433 2018-08-11 2018-08-16
# 8990        2138    2139  US-2018-157896 2018-11-16 2018-11-16
# 8991        4508    4509  US-2015-138247 2015-12-24 2015-12-29
# 8992         365     366  CA-2015-123344 2015-09-24 2015-09-29
# 8993        1454    1455  CA-2017-133711 2017-11-26 2017-11-29
#
#            Ship Mode Customer ID     Customer Name      Segment  \
# 0     Standard Class    SN-20560      Skye Norling  Home Office
# 1     Standard Class    GZ-14470     Gary Zandusky     Consumer
# ...

# %%
data.to_excel('data_90_new.xlsx', index=False, header=True)
